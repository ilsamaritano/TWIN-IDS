# %% [markdown]
# # TWIN-IDS Overview
# This notebook loads experiment outputs and provides quick plots for review.

# %%
import pandas as pd
import matplotlib.pyplot as plt

rq1 = pd.read_csv('../results/rq1_cost_efficiency.csv')
rq1

# %%
ax = rq1.plot(x='budget', y=['compromise_rate', 'detection_rate'], marker='o')
ax.set_title('RQ1: Cost-Efficiency Trend')
ax.grid(True, alpha=0.3)
plt.show()
